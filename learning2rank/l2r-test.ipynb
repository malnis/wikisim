# %%
# testing the listwise learning to rank from https://github.com/shiba24/learning2rank
from rank import ListNet
import numpy as np

Model = ListNet.ListNet()

X = np.array([[3,1,6,4,0], [7,2,6,1,0], [4,0,1,6,5], [3,1,3,4,7], [1,6,3,4,3], [3,6,9,4,1]])
y = np.array([0, 0, 0, 0, 0, 0])

Model.fit(X, y)
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# load dataset
# ('The number of data, train:', 5, 'validate:', 1)
# prepare initialized model!
# Start training and validation loop......
# ('epoch', 1)
# train mean loss=-2.75662326813
# test  mean loss=0.0
# epoch: 2
# NDCG@100 | train: nan, test: nan
# ('epoch', 2)
# train mean loss=0.0
# test  mean loss=0.0
# epoch: 3
# NDCG@100 | train: nan, test: nan
# ('epoch', 3)
# train mean loss=0.0
# test  mean loss=0.0
# epoch: 4
# NDCG@100 | train: nan, test: nan
# ('epoch', 4)
# train mean loss=0.0
# test  mean loss=0.0
# epoch: 5
# NDCG@100 | train: nan, test: nan
# ('epoch', 5)
# train mean loss=0.0
# test  mean loss=0.0
# epoch: 6
# NDCG@100 | train: nan, test: nan
# ('epoch', 6)
# train mean loss=0.0
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# test  mean loss=0.0
# epoch: 7
# NDCG@100 | train: nan, test: nan
# ('epoch', 7)
# train mean loss=0.0
# test  mean loss=0.0
# epoch: 8
# NDCG@100 | train: nan, test: nan
# ('epoch', 8)
# ...

# %%
Model.predict(np.array([[7,2,6,1,0], [3,1,3,4,7]]))
# Out:
# array([[ nan],
#        [ nan]], dtype=float32)
